# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import datetime
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
#ticker
ticker_symbol = "VOO"

# %%
#Get data
ticker = yf.Ticker(ticker_symbol)
data = ticker.history(period="max")

print(data)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-09-09 00:00:00-04:00   77.890928   77.890928   76.857448   76.994232
# 2010-09-10 00:00:00-04:00   77.267791   77.404575   76.979026   77.343781
# 2010-09-13 00:00:00-04:00   78.240470   78.377254   77.890911   78.316460
# 2010-09-14 00:00:00-04:00   78.149314   78.635663   77.799756   78.301300
# 2010-09-15 00:00:00-04:00   77.982108   78.559636   77.814927   78.498848
# ...                               ...         ...         ...         ...
# 2025-10-15 00:00:00-04:00  613.070007  616.210022  605.820007  611.429993
# 2025-10-16 00:00:00-04:00  613.109985  614.799988  604.140015  607.390015
# 2025-10-17 00:00:00-04:00  606.340027  612.020020  605.099976  610.760010
# 2025-10-20 00:00:00-04:00  613.510010  618.010010  613.510010  617.169983
# 2025-10-21 00:00:00-04:00  617.330017  618.719971  615.981018  617.090027
#
#                             Volume  Dividends  Stock Splits  Capital Gains
# Date
# 2010-09-09 00:00:00-04:00    26500        0.0           0.0            0.0
# 2010-09-10 00:00:00-04:00     8600        0.0           0.0            0.0
# 2010-09-13 00:00:00-04:00    33750        0.0           0.0            0.0
# 2010-09-14 00:00:00-04:00    59400        0.0           0.0            0.0
# 2010-09-15 00:00:00-04:00     9250        0.0           0.0            0.0
# ...                            ...        ...           ...            ...
# 2025-10-15 00:00:00-04:00  6504900        0.0           0.0            0.0
# 2025-10-16 00:00:00-04:00  7594800        0.0           0.0            0.0
# 2025-10-17 00:00:00-04:00  6911000        0.0           0.0            0.0
# 2025-10-20 00:00:00-04:00  4086200        0.0           0.0            0.0
# 2025-10-21 00:00:00-04:00  4166416        0.0           0.0            0.0
#
# [3803 rows x 8 columns]

# %%
#Predicting whether the stock price will go up or down in 90 days
data["90Days"]=data["Close"].shift(-90)

#Create target variable
data["Target"]=(data["90Days"]>data["Close"]).astype(int)


data.head()
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2010-09-09 00:00:00-04:00  77.890928  77.890928  76.857448  76.994232   26500
# 2010-09-10 00:00:00-04:00  77.267791  77.404575  76.979026  77.343781    8600
# 2010-09-13 00:00:00-04:00  78.240470  78.377254  77.890911  78.316460   33750
# 2010-09-14 00:00:00-04:00  78.149314  78.635663  77.799756  78.301300   59400
# 2010-09-15 00:00:00-04:00  77.982108  78.559636  77.814927  78.498848    9250
#
#                            Dividends  Stock Splits  Capital Gains     90Days  \
# Date
# 2010-09-09 00:00:00-04:00        0.0           0.0            0.0  90.953064
# 2010-09-10 00:00:00-04:00        0.0           0.0            0.0  90.047394
# 2010-09-13 00:00:00-04:00        0.0           0.0            0.0  89.939919
# 2010-09-14 00:00:00-04:00        0.0           0.0            0.0  90.139481
# 2010-09-15 00:00:00-04:00        0.0           0.0            0.0  90.692123
#
#                            Target
# Date
# 2010-09-09 00:00:00-04:00       1
# 2010-09-10 00:00:00-04:00       1
# 2010-09-13 00:00:00-04:00       1
# 2010-09-14 00:00:00-04:00       1
# 2010-09-15 00:00:00-04:00       1

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  3803.000000  3803.000000  3803.000000  3803.000000  3.803000e+03
# mean    249.922627   251.212298   248.498819   249.962029  3.007436e+06
# std     136.942488   137.659658   136.149599   136.970320  2.889662e+06
# min      77.237400    77.404575    76.536233    76.994232  8.600000e+03
# 25%     144.714406   145.676841   144.001095   144.866127  1.117300e+06
# 50%     216.664343   217.597232   214.906441   216.465546  2.416850e+06
# 75%     356.427686   358.805484   354.190865   357.597107  4.102850e+06
# max     619.229980   619.599976   615.981018   618.770020  3.541800e+07
#
#          Dividends  Stock Splits  Capital Gains       90Days       Target
# count  3803.000000   3803.000000         3803.0  3713.000000  3803.000000
# mean      0.018316      0.000131            0.0   253.985797     0.772022
# std       0.152097      0.008108            0.0   136.129004     0.419583
# min       0.000000      0.000000            0.0    78.172302     0.000000
# 25%       0.000000      0.000000            0.0   148.907928     1.000000
# 50%       0.000000      0.000000            0.0   219.804871     1.000000
# 75%       0.000000      0.000000            0.0   359.301910     1.000000
# max       1.812000      0.500000            0.0   618.770020     1.000000

# %% [markdown]
# The dataset is not that balanced. Need to balance the dataset due to the target mean being 0.77.

# %%
plt.figure(figsize=(15,5))
plt.plot(data['Close'])
plt.title('Close Price Over Time', fontsize=15)
plt.ylabel('Price in dollars.')
plt.show()

# %% [markdown]
# # Machine Learning

# %%
#Define features for ML and Target Variables
features = data[["Open", "High", "Low", "Close", "Volume"]]
target = data['Target']

features_scaled = StandardScaler().fit_transform(features)

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features_scaled, target, test_size=0.2, random_state=42)

# Check the shapes of the resulting datasets
print("Training set shape:", X_train.shape)
print("Testing set shape:", X_test.shape)
# Out:
# Training set shape: (3042, 5)
# Testing set shape: (761, 5)

# %%
#Create Random Forest Model
model = RandomForestClassifier(n_estimators=1000, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=1000, random_state=42)

# %%
#Model make predictions
predict = model.predict(X_test)

# %%
#Evaluate the results of the model
accuracy = accuracy_score(y_test, predict)
print("Accuracy:", accuracy)
classification = classification_report(y_test, predict)
print("Classification Report:")
print(classification)
confusion = confusion_matrix(y_test, predict)
print("Confusion Matrix:")
print(confusion)
# Out:
# Accuracy: 0.8685939553219448
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.66      0.69       169
#            1       0.91      0.93      0.92       592
#
#     accuracy                           0.87       761
#    macro avg       0.81      0.80      0.80       761
# weighted avg       0.87      0.87      0.87       761
#
# Confusion Matrix:
# [[112  57]
#  [ 43 549]]

# %%
#Test Logistic Regression Model
model2 = LogisticRegression(max_iter=1000)
model2.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
#Make predictions
predict2 = model2.predict(X_test)

# %%
#Evaluate the results of the model
accuracy = accuracy_score(y_test, predict2)
print("Accuracy:", accuracy)
classification = classification_report(y_test, predict2)
print("Classification Report:")
print(classification)
confusion = confusion_matrix(y_test, predict2)
print("Confusion Matrix:")
print(confusion)
# Out:
# Accuracy: 0.7779237844940867
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       169
#            1       0.78      1.00      0.88       592
#
#     accuracy                           0.78       761
#    macro avg       0.39      0.50      0.44       761
# weighted avg       0.61      0.78      0.68       761
#
# Confusion Matrix:
# [[  0 169]
#  [  0 592]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#Create SVM Model
model3 = SVC(kernel='rbf')
model3.fit(X_train, y_train)
# Out:
# SVC()

# %%
#Make predictions
predict3 = model3.predict(X_test)

# %%
#Evaluate the results of the model
accuracy = accuracy_score(y_test, predict3)
print("Accuracy:", accuracy)
classification = classification_report(y_test, predict3)
print("Classification Report:")
print(classification)
confusion = confusion_matrix(y_test, predict3)
print("Confusion Matrix:")
print(confusion)
# Out:
# Accuracy: 0.8028909329829172
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.15      0.26       169
#            1       0.80      0.99      0.89       592
#
#     accuracy                           0.80       761
#    macro avg       0.80      0.57      0.57       761
# weighted avg       0.80      0.80      0.75       761
#
# Confusion Matrix:
# [[ 26 143]
#  [  7 585]]

# %%
#XGBoost
model4 = XGBClassifier()
model4.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
predict4 = model4.predict(X_test)

# %%
#Evaluate the results of the model
accuracy = accuracy_score(y_test, predict4)
print("Accuracy:", accuracy)
classification = classification_report(y_test, predict4)
print("Classification Report:")
print(classification)
confusion = confusion_matrix(y_test, predict4)
print("Confusion Matrix:")
print(confusion)
# Out:
# Accuracy: 0.8633377135348226
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.60      0.66       169
#            1       0.89      0.94      0.91       592
#
#     accuracy                           0.86       761
#    macro avg       0.81      0.77      0.79       761
# weighted avg       0.86      0.86      0.86       761
#
# Confusion Matrix:
# [[101  68]
#  [ 36 556]]

# %% [markdown]
# Next 180 days Prediction Using XGBoost

# %%
last_day_data = data.tail(1)
print(last_day_data)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-10-21 00:00:00-04:00  617.330017  618.719971  615.981018  617.090027
#
#                             Volume  Dividends  Stock Splits  Capital Gains  \
# Date
# 2025-10-21 00:00:00-04:00  4166416        0.0           0.0            0.0
#
#                            90Days  Target
# Date
# 2025-10-21 00:00:00-04:00     NaN       0

# %%
new_features = last_day_data[["Open", "High", "Low", "Close", "Volume"]]
new_features_scaled = StandardScaler().fit_transform(new_features)
predict4 = model4.predict(new_features_scaled)
print(predict4)
# Out:
# [1]

# %%
if predict4[0] == 1:
    print("The stock price will go up over the next 90 days.")
else:
    print("The stock price will go down or stay the same over the next 90 days.")
# Out:
# The stock price will go up over the next 90 days.
